# %%
meses = gdf.groupby(
    'mes'
)['area_ha'].sum()

meses.plot(
    marker='o',
    figsize=(8,5)
)

plt.title(
    'Evolução mensal do desmatamento'
)

plt.ylabel('Hectares')

plt.xlabel('Mês')

plt.grid()

plt.show()
